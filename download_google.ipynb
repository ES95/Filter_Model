# %%
from google_images_download import google_images_download   #importing the library
import pandas as pd

# %%
response = google_images_download.googleimagesdownload()   #class instantiation

# %%
logo=pd.read_csv(r"C:\Users\eklavya\Desktop\official_channels.csv")['channel']
for x in logo:
    arguments = {"keywords":x+' logo',"limit":50,"print_urls":True}   #creating list of argume
    paths = response.download(arguments)   #passing the arguments to the function
    print(paths)
# Out:
# Item no.: 1 --> Item name = alfa romeo logo
# Evaluating...
# Starting Download...
# Image URL: https://www.alfaromeousa.com/content/alfausa/en/the-badge/_jcr_content/main/badge_head/main-logo.img.png/1519407197544.png
# Completed Image ====> 1. 1519407197544.png
# Image URL: https://www.carlogos.org/logo/Alfa-Romeo-logo-2015-1920x1080.png
# Completed Image ====> 2. alfa-romeo-logo-2015-1920x1080.png
# Image URL: https://illuminatisymbols.info/wp-content/uploads/alfa-romeo-logo-illuminati-symbolism.jpg
# Completed Image ====> 3. alfa-romeo-logo-illuminati-symbolism.jpg
# Image URL: https://www.museodelmarchioitaliano.it/marchi/img/alfa-romeo/marchio-alfa-romeo-15.jpg
# Completed Image ====> 4. marchio-alfa-romeo-15.jpg
# Image URL: https://www.fiatofkirkland.com/blogs/1227/wp-content/uploads/2015/01/Alfa_Romeo_logo_evolution-1.jpg
# Completed Image ====> 5. alfa_romeo_logo_evolution-1.jpg
# Image URL: https://i.ebayimg.com/images/g/c0EAAOxyDo1Tje9D/s-l640.jpg
# ...

# %%
from google_images_download import google_images_download   #importing the library

response = google_images_download.googleimagesdownload()   #class instantiation

arguments = {"keywords":"Polar bears,baloons,Beaches","limit":20,"print_urls":True}   #creating list of arguments
paths = response.download(arguments)   #passing the arguments to the function
print(paths)   #printing absolute paths of the downloaded images
# Out:
#   File "<ipython-input-10-102655ae08e3>", line 1
#     arguments = {'zzz',"limit":50,"print_urls":True}   #creating list of argume
#                               ^
# SyntaxError: invalid syntax

# %%
الجعة,Beer,
الخمور,Wines,
تكيلا,Tequila,
رم شراب مسكر,rum,
شرك,gin,
فودكا,vodka,
كحول,booze,
كحولي,alcoholic,
نوع من الخمر,Vermouth,
ويسكي,whiskey

# %%
arguments = {"keywords":"الجعة,Beer,الخمور,Wines,تكيلا,Tequila,رم شراب مسكر,rum,شرك,gin,فودكا,vodka,كحول,booze,كحولي,alcoholic,نوع من الخمر,Vermouth,ويسكي,whiskey","limit":50,"print_urls":True}   #creating list of arguments
paths = response.download(arguments)   #passing the arguments to the function
print(paths)   #printing absolute paths of the downloaded images
# Out:
# Item no.: 1 --> Item name = الجعة
# Evaluating...
# Starting Download...
# Image URL: https://raseef22.com/wp-content/uploads/2014/10/Almaza.jpg
# Completed Image ====> 1. almaza.jpg
# Image URL: https://upload.wikimedia.org/wikipedia/commons/5/57/Beer_Cans-1.jpg
# Completed Image ====> 2. beer_cans-1.jpg
# Image URL: https://data.arab48.com/data/news/2015/09/08/Croped/20150908172727.jpg
# Completed Image ====> 3. 20150908172727.jpg
# Image URL: https://upload.wikimedia.org/wikipedia/commons/thumb/a/a2/Paulaner_Oktoberfest_Marzen_11.2oz_bottle_and_beer_mug.jpg/220px-Paulaner_Oktoberfest_Marzen_11.2oz_bottle_and_beer_mug.jpg
# Completed Image ====> 4. 220px-paulaner_oktoberfest_marzen_11.2oz_bottle_and_beer_mug.jpg
# Image URL: https://khaberni-6zrocpuaymq7.stackpathdns.com/uploads/news_model/2017/10/main_image59d24d0d68972.jpg
# Completed Image ====> 5. main_image59d24d0d68972.jpg
# Image URL: https://raseef22.com/wp-content/uploads/2014/10/Casablanca-beer.jpg
# ...
